# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense, Activation, RepeatVector
from keras.layers.recurrent import LSTM
from keras.layers.wrappers import TimeDistributed
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

np.random.seed(0)

# %%
def n(digits=3):
    number = ''
    for i in range(np.random.randint(1, digits + 1)):
        number += np.random.choice(list('0123456789'))
    return int(number)


def padding(chars, maxlen):
    return chars + ' ' * (maxlen - len(chars))

# %%
'''
データの生成
'''
N = 20000
N_train = int(N * 0.9)
N_validation = N - N_train

digits = 3  # 最大の桁数
input_digits = digits * 2 + 1  # 例： 123+456
output_digits = digits + 1  # 500+500 = 1000 以上で４桁になる

added = set()
questions = []
answers = []

while len(questions) < N:
    a, b = n(), n()  # 適当な数を２つ生成

    pair = tuple(sorted((a, b)))
    if pair in added:
        continue

    question = '{}+{}'.format(a, b)
    question = padding(question, input_digits)
    answer = str(a + b)
    answer = padding(answer, output_digits)

    added.add(pair)
    questions.append(question)
    answers.append(answer)

chars = '0123456789+ '
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

X = np.zeros((len(questions), input_digits, len(chars)), dtype=np.integer)
Y = np.zeros((len(questions), digits + 1, len(chars)), dtype=np.integer)

for i in range(N):
    for t, char in enumerate(questions[i]):
        X[i, t, char_indices[char]] = 1
    for t, char in enumerate(answers[i]):
        Y[i, t, char_indices[char]] = 1

X_train, X_validation, Y_train, Y_validation = \
    train_test_split(X, Y, train_size=N_train)

# %%
'''
モデル設定
'''
n_in = len(chars)
n_hidden = 128
n_out = len(chars)

model = Sequential()

# Encoder
model.add(LSTM(n_hidden, input_shape=(input_digits, n_in)))

# Decoder
model.add(RepeatVector(output_digits))
model.add(LSTM(n_hidden, return_sequences=True))

model.add(TimeDistributed(Dense(n_out)))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
              metrics=['accuracy'])

# %%
a = "aaaa"
b = "bbbb"
print ('a:', a, 'b:',b)
# Out:
# a: aaaa b: bbbb

# %%
'''
モデル学習
'''
epochs = 10
batch_size = 100

for epoch in range(epochs):
    print("epoch / epochs: ", (epoch + 1), "/", epochs)
    model.fit(X_train, Y_train, batch_size=batch_size, epochs=1,
              validation_data=(X_validation, Y_validation))

    # 検証データからランダムに問題を選んで答え合わせ
    for i in range(10):
        index = np.random.randint(0, N_validation)
        question = X_validation[np.array([index])]
        answer = Y_validation[np.array([index])]
        prediction = model.predict_classes(question, verbose=0)

        question = question.argmax(axis=-1)
        answer = answer.argmax(axis=-1)

        q = ''.join(indices_char[i] for i in question[0])
        a = ''.join(indices_char[i] for i in answer[0])
        p = ''.join(indices_char[i] for i in prediction[0])

        #print('-' * 10)
        #print('Q:  ', q, 'A:  ', p, 'T/F:', end=' ')
        #if a == p:
        #    print('TRUE')
        #else:
        #    print('FALSE')
# Out:
# epoch / epochs:  1 / 10
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 13s - loss: 1.9177e-04 - acc: 1.0000 - val_loss: 0.2700 - val_acc: 0.9425
# epoch / epochs:  2 / 10
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 13s - loss: 1.8332e-04 - acc: 1.0000 - val_loss: 0.2709 - val_acc: 0.9419
# epoch / epochs:  3 / 10
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 13s - loss: 1.7539e-04 - acc: 1.0000 - val_loss: 0.2721 - val_acc: 0.9416
# epoch / epochs:  4 / 10
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - ETA: 7s - loss: 1.6263e-04 - acc: 1.0000
# epoch / epochs:  5 / 10
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 13s - loss: 1.6033e-04 - acc: 1.0000 - val_loss: 0.2750 - val_acc: 0.9412
# epoch / epochs:  6 / 10
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - ETA: 10s - loss: 1.5336e-04 - acc: 1.0000
# epoch / epochs:  7 / 10
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 13s - loss: 1.4727e-04 - acc: 1.0000 - val_loss: 0.2763 - val_acc: 0.9407
# epoch / epochs:  8 / 10
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 13s - loss: 1.3981e-04 - acc: 1.0000 - val_loss: 0.2800 - val_acc: 0.9425
# epoch / epochs:  9 / 10
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 13s - loss: 1.3260e-04 - acc: 1.0000 - val_loss: 0.2821 - val_acc: 0.9411
# epoch / epochs:  10 / 10
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 13s - loss: 1.2731e-04 - acc: 1.0000 - val_loss: 0.2808 - val_acc: 0.9414

# %%
from keras.models import load_model

model.save('encoder_decoder_model.h5')  # creates a HDF5 file

# %%
'''
予測精度の評価
'''

questions_count = 1000
success_count = 0

for i in range(questions_count):
    index = np.random.randint(0, N_validation)
    question = X_validation[np.array([index])]
    answer = Y_validation[np.array([index])]
    prediction = model.predict_classes(question, verbose=0)

    question = question.argmax(axis=-1)
    answer = answer.argmax(axis=-1)

    q = ''.join(indices_char[i] for i in question[0])
    a = ''.join(indices_char[i] for i in answer[0])
    p = ''.join(indices_char[i] for i in prediction[0])

#    print('-' * 10)
 #   print('Q:  ', q, 'A:  ', p, 'T/F:', end=' ')
#        print('A:  ', p)
#        print('T/F:', end=' ')
    if a == p:
        success_count += 1 
#        print('TRUE')
    else:
        print('Q:  ', q, 'A:  ', p, 'T/F:', end=' ')
        print('FALSE')

accuracy = success_count / questions_count
print("success_count: ",success_count, "/",questions_count)
print("accuracy: ",accuracy)
# Out:
# Q:   101+447 A:   558  T/F: FALSE
# Q:   537+3   A:   530  T/F: FALSE
# Q:   371+446 A:   827  T/F: FALSE
# Q:   47+823  A:   860  T/F: FALSE
# Q:   727+526 A:   1143 T/F: FALSE
# Q:   69+170  A:   249  T/F: FALSE
# Q:   261+801 A:   162  T/F: FALSE
# Q:   395+667 A:   1053 T/F: FALSE
# Q:   520+912 A:   1422 T/F: FALSE
# Q:   463+445 A:   809  T/F: FALSE
# Q:   15+149  A:   174  T/F: FALSE
# Q:   442+908 A:   1351 T/F: FALSE
# Q:   502+1   A:   502  T/F: FALSE
# Q:   864+249 A:   1103 T/F: FALSE
# Q:   847+934 A:   1721 T/F: FALSE
# Q:   836+282 A:   1108 T/F: FALSE
# Q:   235+963 A:   1298 T/F: FALSE
# Q:   375+780 A:   1145 T/F: FALSE
# Q:   419+994 A:   1403 T/F: FALSE
# Q:   462+38  A:   400  T/F: FALSE
# Q:   552+7   A:   569  T/F: FALSE
# Q:   334+174 A:   408  T/F: FALSE
# Q:   82+837  A:   929  T/F: FALSE
# Q:   408+95  A:   403  T/F: FALSE
# Q:   603+19  A:   621  T/F: FALSE
# Q:   393+300 A:   793  T/F: FALSE
# Q:   727+526 A:   1143 T/F: FALSE
# Q:   847+934 A:   1721 T/F: FALSE
# Q:   25+925  A:   940  T/F: FALSE
# Q:   579+416 A:   905  T/F: FALSE
# Q:   101+447 A:   558  T/F: FALSE
# Q:   374+119 A:   483  T/F: FALSE
# Q:   69+429  A:   408  T/F: FALSE
# Q:   275+66  A:   331  T/F: FALSE
# Q:   984+961 A:   1935 T/F: FALSE
# Q:   616+513 A:   1229 T/F: FALSE
# Q:   812+48  A:   850  T/F: FALSE
# Q:   430+16  A:   456  T/F: FALSE
# Q:   45+473  A:   508  T/F: FALSE
# Q:   45+45   A:   80   T/F: FALSE
# Q:   836+282 A:   1108 T/F: FALSE
# Q:   86+3    A:   99   T/F: FALSE
# Q:   110+317 A:   228  T/F: FALSE
# Q:   867+41  A:   918  T/F: FALSE
# Q:   127+897 A:   1134 T/F: FALSE
# Q:   832+47  A:   889  T/F: FALSE
# Q:   704+71  A:   774  T/F: FALSE
# Q:   375+780 A:   1145 T/F: FALSE
# Q:   667+870 A:   1547 T/F: FALSE
# Q:   586+745 A:   1321 T/F: FALSE
# Q:   662+8   A:   660  T/F: FALSE
# Q:   395+667 A:   1053 T/F: FALSE
# Q:   62+338  A:   300  T/F: FALSE
# Q:   804+802 A:   1615 T/F: FALSE
# Q:   409+834 A:   1233 T/F: FALSE
# Q:   116+49  A:   175  T/F: FALSE
# Q:   702+66  A:   778  T/F: FALSE
# Q:   823+989 A:   1802 T/F: FALSE
# Q:   686+861 A:   1557 T/F: FALSE
# Q:   818+540 A:   1368 T/F: FALSE
# Q:   27+60   A:   77   T/F: FALSE
# Q:   579+416 A:   905  T/F: FALSE
# Q:   27+992  A:   1010 T/F: FALSE
# Q:   36+684  A:   710  T/F: FALSE
# Q:   419+994 A:   1403 T/F: FALSE
# Q:   401+778 A:   1189 T/F: FALSE
# Q:   414+94  A:   408  T/F: FALSE
# Q:   38+32   A:   60   T/F: FALSE
# Q:   9+136   A:   144  T/F: FALSE
# Q:   629+269 A:   998  T/F: FALSE
# Q:   281+764 A:   1065 T/F: FALSE
# Q:   472+154 A:   616  T/F: FALSE
# Q:   27+60   A:   77   T/F: FALSE
# Q:   847+934 A:   1721 T/F: FALSE
# Q:   888+309 A:   1297 T/F: FALSE
# Q:   537+3   A:   530  T/F: FALSE
# Q:   732+631 A:   1344 T/F: FALSE
# Q:   583+135 A:   708  T/F: FALSE
# Q:   138+660 A:   708  T/F: FALSE
# Q:   31+121  A:   142  T/F: FALSE
# Q:   589+527 A:   1115 T/F: FALSE
# Q:   527+734 A:   1170 T/F: FALSE
# Q:   17+483  A:   490  T/F: FALSE
# Q:   217+387 A:   594  T/F: FALSE
# Q:   427+839 A:   1276 T/F: FALSE
# Q:   527+734 A:   1170 T/F: FALSE
# Q:   217+387 A:   594  T/F: FALSE
# Q:   46+928  A:   964  T/F: FALSE
# Q:   370+89  A:   469  T/F: FALSE
# Q:   7+27    A:   35   T/F: FALSE
# Q:   27+992  A:   1010 T/F: FALSE
# Q:   410+981 A:   1301 T/F: FALSE
# Q:   813+178 A:   980  T/F: FALSE
# Q:   371+323 A:   614  T/F: FALSE
# Q:   167+102 A:   288  T/F: FALSE
# Q:   393+695 A:   1079 T/F: FALSE
# Q:   167+102 A:   288  T/F: FALSE
# Q:   38+97   A:   145  T/F: FALSE
# Q:   867+41  A:   918  T/F: FALSE
# Q:   552+7   A:   569  T/F: FALSE
# Q:   997+767 A:   1744 T/F: FALSE
# Q:   735+76  A:   821  T/F: FALSE
# Q:   9+136   A:   144  T/F: FALSE
# Q:   579+416 A:   905  T/F: FALSE
# Q:   869+4   A:   863  T/F: FALSE
# Q:   874+497 A:   1271 T/F: FALSE
# Q:   960+479 A:   1420 T/F: FALSE
# Q:   74+676  A:   740  T/F: FALSE
# Q:   410+981 A:   1301 T/F: FALSE
# Q:   949+93  A:   1032 T/F: FALSE
# Q:   969+989 A:   1978 T/F: FALSE
# Q:   968+242 A:   1229 T/F: FALSE
# Q:   949+905 A:   1804 T/F: FALSE
# Q:   84+498  A:   583  T/F: FALSE
# Q:   533+16  A:   559  T/F: FALSE
# Q:   45+45   A:   80   T/F: FALSE
# Q:   752+621 A:   1383 T/F: FALSE
# Q:   217+387 A:   594  T/F: FALSE
# Q:   823+989 A:   1802 T/F: FALSE
# Q:   951+66  A:   1027 T/F: FALSE
# Q:   663+17  A:   670  T/F: FALSE
# Q:   672+699 A:   1461 T/F: FALSE
# Q:   0+809   A:   899  T/F: FALSE
# Q:   952+966 A:   1929 T/F: FALSE
# Q:   812+48  A:   850  T/F: FALSE
# Q:   804+802 A:   1615 T/F: FALSE
# Q:   681+407 A:   1087 T/F: FALSE
# Q:   276+215 A:   490  T/F: FALSE
# Q:   792+346 A:   1228 T/F: FALSE
# Q:   804+802 A:   1615 T/F: FALSE
# Q:   827+3   A:   820  T/F: FALSE
# Q:   815+353 A:   1068 T/F: FALSE
# Q:   69+170  A:   249  T/F: FALSE
# Q:   714+584 A:   1398 T/F: FALSE
# Q:   216+680 A:   906  T/F: FALSE
# Q:   725+371 A:   1087 T/F: FALSE
# Q:   491+116 A:   507  T/F: FALSE
# Q:   27+992  A:   1010 T/F: FALSE
# Q:   408+491 A:   990  T/F: FALSE
# Q:   965+131 A:   1107 T/F: FALSE
# Q:   862+57  A:   929  T/F: FALSE
# Q:   3+347   A:   340  T/F: FALSE
# Q:   995+602 A:   1607 T/F: FALSE
# Q:   504+925 A:   1438 T/F: FALSE
# Q:   113+127 A:   230  T/F: FALSE
# Q:   414+94  A:   408  T/F: FALSE
# Q:   796+117 A:   903  T/F: FALSE
# Q:   718+746 A:   1454 T/F: FALSE
# Q:   949+905 A:   1804 T/F: FALSE
# Q:   758+837 A:   1505 T/F: FALSE
# Q:   657+437 A:   1104 T/F: FALSE
# Q:   731+261 A:   900  T/F: FALSE
# Q:   245+27  A:   271  T/F: FALSE
# Q:   758+837 A:   1505 T/F: FALSE
# Q:   515+436 A:   941  T/F: FALSE
# Q:   706+110 A:   826  T/F: FALSE
# Q:   430+16  A:   456  T/F: FALSE
# Q:   197+409 A:   506  T/F: FALSE
# Q:   579+306 A:   775  T/F: FALSE
# Q:   197+409 A:   506  T/F: FALSE
# Q:   965+131 A:   1107 T/F: FALSE
# Q:   527+734 A:   1170 T/F: FALSE
# Q:   398+21  A:   429  T/F: FALSE
# Q:   342+98  A:   430  T/F: FALSE
# Q:   343+957 A:   1209 T/F: FALSE
# Q:   8+282   A:   280  T/F: FALSE
# Q:   35+895  A:   920  T/F: FALSE
# Q:   533+16  A:   559  T/F: FALSE
# Q:   292+802 A:   1174 T/F: FALSE
# Q:   288+489 A:   767  T/F: FALSE
# Q:   939+370 A:   1399 T/F: FALSE
# Q:   313+142 A:   465  T/F: FALSE
# Q:   552+7   A:   569  T/F: FALSE
# Q:   2+549   A:   552  T/F: FALSE
# Q:   160+120 A:   270  T/F: FALSE
# Q:   579+416 A:   905  T/F: FALSE
# Q:   151+611 A:   772  T/F: FALSE
# Q:   686+861 A:   1557 T/F: FALSE
# Q:   288+489 A:   767  T/F: FALSE
# Q:   392+428 A:   860  T/F: FALSE
# Q:   404+702 A:   1116 T/F: FALSE
# Q:   686+861 A:   1557 T/F: FALSE
# Q:   418+585 A:   9033 T/F: FALSE
# Q:   31+252  A:   282  T/F: FALSE
# Q:   209+215 A:   433  T/F: FALSE
# Q:   167+102 A:   288  T/F: FALSE
# Q:   527+474 A:   901  T/F: FALSE
# Q:   395+667 A:   1053 T/F: FALSE
# Q:   951+66  A:   1027 T/F: FALSE
# Q:   472+154 A:   616  T/F: FALSE
# Q:   116+49  A:   175  T/F: FALSE
# Q:   9+136   A:   144  T/F: FALSE
# Q:   243+746 A:   999  T/F: FALSE
# Q:   682+849 A:   1522 T/F: FALSE
# Q:   7+27    A:   35   T/F: FALSE
# Q:   338+759 A:   1087 T/F: FALSE
# Q:   84+498  A:   583  T/F: FALSE
# Q:   47+823  A:   860  T/F: FALSE
# Q:   948+295 A:   1224 T/F: FALSE
# Q:   209+215 A:   433  T/F: FALSE
# Q:   216+680 A:   906  T/F: FALSE
# Q:   853+505 A:   1338 T/F: FALSE
# Q:   46+928  A:   964  T/F: FALSE
# Q:   939+370 A:   1399 T/F: FALSE
# Q:   792+346 A:   1228 T/F: FALSE
# Q:   116+49  A:   175  T/F: FALSE
# success_count:  794 / 1000
# accuracy:  0.794
